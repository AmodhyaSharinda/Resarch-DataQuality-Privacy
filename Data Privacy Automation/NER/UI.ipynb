# %%
import streamlit as st
import pandas as pd

# -------------------------
# Dummy functions (replace with your real logic)
# -------------------------

def detect_entities(text):
    """
    Replace with your NER + Regex pipeline
    """
    return [
        {"text": "John Doe", "type": "NAME"},
        {"text": "john@gmail.com", "type": "EMAIL"}
    ]

def assign_privacy(entity_type):
    privacy_map = {
        "NAME": "High",
        "EMAIL": "Medium",
        "PHONE": "Medium"
    }
    return privacy_map.get(entity_type, "Low")

def encrypt(value, method):
    return f"[{method}::{value}]"

# -------------------------
# Streamlit UI
# -------------------------

st.set_page_config(page_title="Real-Time Privacy Preservation Demo", layout="wide")

st.title("🔐 Real-Time Privacy Preservation in Data Pipelines")
st.caption("Detect → Classify → Encrypt → Replace")

# 1️⃣ User Input
input_text = st.text_area(
    "Enter input text",
    placeholder="John Doe's email is john@gmail.com",
    height=150
)

if st.button("Process Text"):

    if not input_text.strip():
        st.warning("Please enter some text.")
        st.stop()

    # 2️⃣ Entity Detection
    entities = detect_entities(input_text)

    results = []
    for ent in entities:
        privacy = assign_privacy(ent["type"])
        results.append({
            "Entity": ent["text"],
            "Type": ent["type"],
            "Privacy Level": privacy
        })

    df = pd.DataFrame(results)

    st.subheader("🔍 Detected Sensitive Entities")
    st.dataframe(df, use_container_width=True)

    # 3️⃣ Encryption Selection
    st.subheader("🔑 Encryption Selection")

    encryption_choices = {}
    for idx, row in df.iterrows():
        options = ["Masking", "Hashing", "AES", "Tokenization"]
        default = 2 if row["Privacy Level"] == "High" else 1

        encryption_choices[row["Entity"]] = st.selectbox(
            f"Encryption for `{row['Entity']}` ({row['Type']})",
            options,
            index=default,
            key=row["Entity"]
        )

    # 4️⃣ Replace with Encrypted Values
    safe_text = input_text
    for entity, method in encryption_choices.items():
        encrypted_value = encrypt(entity, method)
        safe_text = safe_text.replace(entity, encrypted_value)

    st.subheader("✅ Privacy-Preserved Output")
    st.code(safe_text, language="text")
# Out:
# 2026-01-05 07:11:05.036 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.036 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\ADMIN\Desktop\Research\Data Privacy Automation\myenv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.495 Session state does not function when running a script without `streamlit run`
# 2026-01-05 07:11:05.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-05 07:11:05.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.52.2-py3-none-any.whl.metadata (9.8 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging>=20 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (22.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (9.1.2)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Collecting narwhals>=1.27.1 (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\desktop\research\data privacy automation\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.52.2-py3-none-any.whl (9.0 MB)
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.0 MB 4.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/9.0 MB 4.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.0 MB 4.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/9.0 MB 3.5 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.0 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/9.0 MB 3.6 MB/s eta 0:00:02
#    -------------------------- ------------- 6.0/9.0 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.8/9.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.9/9.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  8.9/9.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.0/9.0 MB 3.9 MB/s eta 0:00:00
# Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#    ---------------------------------------- 0.0/795.4 kB ? eta -:--:--
#    ---------------------------------------- 795.4/795.4 kB 5.7 MB/s eta 0:00:00
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, smmap, narwhals, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-6.0.0 blinker-1.9.0 gitdb-4.0.12 gitpython-3.1.46 narwhals-2.14.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.52.2 toml-0.10.2 watchdog-6.0.0
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
